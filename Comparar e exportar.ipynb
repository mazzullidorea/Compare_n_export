# %%
import pandas as pd
import os
import openpyxl
import random
import datetime

# Verificar se o arquivo de texto existe
file_path = 'Primeira quinzena.txt'
if not os.path.exists(file_path):
    print(f'O arquivo {file_path} não existe!')
    exit()

# Ler os caminhos de arquivo do arquivo de texto
with open(file_path, 'r') as f:
    file_paths = f.read().splitlines()

faturas_utilizadas = [] # lista de numeros de fatura ja utilizados
data_frames = [] # criar uma lista vazia para armazenar os DataFrames

for file_path in file_paths:
    # Verificar se o caminho de arquivo é válido
    if not os.path.exists(file_path):
        print(f'O arquivo {file_path} não existe!')
        continue
    
    # Ler o arquivo Excel e adicionar o DataFrame à lista
    try:
        df = pd.read_excel(file_path, sheet_name=None, usecols='A:D', skiprows=1, nrows=12)
       
        data_frames.append(df)
    except Exception:
        print(f'O arquivo {file_path} não foi reconhecido!')
        
data = {}       
for df in data_frames:
    for sheet_name in df.keys():
        if sheet_name in data:
            data[sheet_name].append(df[sheet_name])
        else:
            data[sheet_name] = [df[sheet_name]]

# Comparar os dados das abas com o mesmo nome nos arquivos Excel
for sheet_name, data_list in data.items():
    for i, data1 in enumerate(data_list):
        for data2 in data_list[i+1:]:
            if not data1.equals(data2):
                print(f"As abas '{sheet_name}' dos arquivos são diferentes.")
            else:
                # Comparar os dados das colunas 'DATA', 'CAPITAL', 'GRANDE SP' e 'NOVAS'
                dados_comparados = {
                    'DATA': data1['DATA'].tolist(),
                    'CAPITAL': data1['CAPITAL'].tolist(),
                    'GRANDE SP': data1['GRANDE SP'].tolist(),
                    'NOVAS': data1['NOVAS'].tolist()
                }

                # abrir a pasta de trabalho e a aba "Demonstrativo"
                workbook = openpyxl.load_workbook('Fatura.xlsx')
                sheet = workbook['Demonstrativo']

                # nome do cliente
                sheet['C11'] = sheet_name
                
                # gerar numero de unico de fatura
                def gerar_numero_fatura():
                    while True:
                        numero_fatura = random.randint(1000000, 9999999)
                        if numero_fatura not in faturas_utilizadas:
                            faturas_utilizadas.append(numero_fatura)
                            return numero_fatura
                            
                numero_fatura = gerar_numero_fatura()
                sheet['C9'] = numero_fatura
                
                # colar os dados
                for col, col_dados in zip(['B', 'C', 'D', 'E'], dados_comparados.values()):
                    for row, dados in enumerate(col_dados, start=15):
                        sheet[f'{col}{row}'] = dados
                
                # data atual
                data_atual = datetime.date.today()
                dtf = data_atual.strftime('%d-%m-%Y')
                sheet['C10'] = dtf
                
                # criar a pasta se ela não existir
                pasta = f'Faturas-{dtf}'
                if not os.path.exists(pasta):
                    os.makedirs(pasta)

                # criar o caminho completo do arquivo
                arquivo = f'{pasta}/Fatura.xlsx'

                # salvar o arquivo  
                try:
                    workbook.save(f'{pasta}/Fatura {sheet_name}-{dtf}.xlsx')
                    print(f'Fatura_{sheet_name}.xlsx salva!')
                except Exception as e:
                    print(f'Erro ao salvar o arquivo Fatura_{sheet_name}.xlsx: {e}')
# Out:
# Fatura_NOEY.xlsx salva!
# Fatura_EDMILSON.xlsx salva!
# Fatura_CORINA.xlsx salva!
# Fatura_VINICIUS.xlsx salva!
# Fatura_APOTECA.xlsx salva!
# Fatura_MARCELO.xlsx salva!
# Fatura_MONIQUE.xlsx salva!
# Fatura_DOCERIA.xlsx salva!
# Fatura_ROMELANDIA.xlsx salva!
# Fatura_JULIO.xlsx salva!
# Fatura_RUGIDO KIDS.xlsx salva!
# Fatura_JOAO .xlsx salva!
# Fatura_VIEIRA MED.xlsx salva!
# Fatura_ANDRE OSASCO.xlsx salva!
# Fatura_CARZOM.xlsx salva!
# Fatura_ALPHASTART.xlsx salva!
# Fatura_4I DISTRIBUIDORA.xlsx salva!
# Fatura_XTREME BIKE SHOP.xlsx salva!
# Fatura_BELLA DAMA.xlsx salva!
# Fatura_FORNEL.xlsx salva!
# Fatura_KAREN.xlsx salva!
# Fatura_UMEC.xlsx salva!
# Fatura_FELIPE MOINHI FABRINI.xlsx salva!
# Fatura_GBM.xlsx salva!
# Fatura_LA GOLD.xlsx salva!
# Fatura_ROBSON MAZZEI.xlsx salva!
# Fatura_MADDLIN LINGERIE.xlsx salva!
# Fatura_GNKIDS.xlsx salva!
# Fatura_VANDERLINO.xlsx salva!
# Fatura_GABI KIDS.xlsx salva!
# Fatura_RENAULT.xlsx salva!
# Fatura_ITAVEMA.xlsx salva!
# Fatura_MUNDO KIDS.xlsx salva!
# Fatura_GIOVANA.xlsx salva!
# Fatura_MAURO ZANI.xlsx salva!
# Fatura_MARI FESTAS.xlsx salva!
# Fatura_VAIDOSA PERFUMARIA.xlsx salva!
# Fatura_FRED.xlsx salva!
# Fatura_CAMILA.xlsx salva!
# Fatura_THIAGO MAZZEI .xlsx salva!
# Fatura_MATHEUS MAZZEI.xlsx salva!
# Fatura_LEANDRO.xlsx salva!
# Fatura_MATHEUS BRUTUS.xlsx salva!
# Fatura_JOEL(GABRIEL).xlsx salva!
# Fatura_CHICO MEIAS(GABRIEL).xlsx salva!
# Fatura_LUCAS PEÇAS MAZZEI.xlsx salva!
# Fatura_FESTA MIX.xlsx salva!
# Fatura_RENATO MULTIVENDAS.xlsx salva!
# Fatura_MISATI (GABRIEL).xlsx salva!
# Fatura_MATHEUS (GABRIEL).xlsx salva!
# Fatura_ATHUR.xlsx salva!
# As abas 'DONA FILÓ' dos arquivos são diferentes.
# Fatura_TURBO FAST.xlsx salva!
# Fatura_ELAINE.xlsx salva!
# Fatura_TTBB.xlsx salva!
# Fatura_ANDRE RICARDO.xlsx salva!
# Fatura_BABY LA.xlsx salva!
# Fatura_DANIEL.xlsx salva!
